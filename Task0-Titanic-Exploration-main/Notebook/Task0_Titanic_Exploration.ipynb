# %%
import pandas as pd

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sd=pd.read_csv('/content/drive/MyDrive/DATA_ANALYTICS_CLUB /ASSIGMENT 1/gender_submission.csv')
sd

# %%
sd1=pd.read_csv('/content/drive/MyDrive/DATA_ANALYTICS_CLUB /ASSIGMENT 1/train.csv')
sd1
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
sd1.hist('Age')
sd1.hist('Fare')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9c420f590>]],
#       dtype=object)

# %%
sd1.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
sd1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sd1=sd1.dropna(axis=1)
sd1
# Out:
#      PassengerId  Survived  Pclass  ... Parch            Ticket     Fare
# 0              1         0       3  ...     0         A/5 21171   7.2500
# 1              2         1       1  ...     0          PC 17599  71.2833
# 2              3         1       3  ...     0  STON/O2. 3101282   7.9250
# 3              4         1       1  ...     0            113803  53.1000
# 4              5         0       3  ...     0            373450   8.0500
# ..           ...       ...     ...  ...   ...               ...      ...
# 886          887         0       2  ...     0            211536  13.0000
# 887          888         1       1  ...     0            112053  30.0000
# 888          889         0       3  ...     2        W./C. 6607  23.4500
# 889          890         1       1  ...     0            111369  30.0000
# 890          891         0       3  ...     0            370376   7.7500
#
# [891 rows x 9 columns]

# %%
sd1=sd1.drop('Name', axis=1)

# %%
sd1=sd1.drop('PassengerId', axis=1)

# %%
sd1
# Out:
#      Survived  Pclass     Sex  SibSp  Parch            Ticket     Fare
# 0           0       3    male      1      0         A/5 21171   7.2500
# 1           1       1  female      1      0          PC 17599  71.2833
# 2           1       3  female      0      0  STON/O2. 3101282   7.9250
# 3           1       1  female      1      0            113803  53.1000
# 4           0       3    male      0      0            373450   8.0500
# ..        ...     ...     ...    ...    ...               ...      ...
# 886         0       2    male      0      0            211536  13.0000
# 887         1       1  female      0      0            112053  30.0000
# 888         0       3  female      1      2        W./C. 6607  23.4500
# 889         1       1    male      0      0            111369  30.0000
# 890         0       3    male      0      0            370376   7.7500
#
# [891 rows x 7 columns]

# %%
set1=sd1.iloc[0:713,:]
set1
# Out:
#      Survived  Pclass     Sex  SibSp  Parch            Ticket      Fare
# 0           0       3    male      1      0         A/5 21171    7.2500
# 1           1       1  female      1      0          PC 17599   71.2833
# 2           1       3  female      0      0  STON/O2. 3101282    7.9250
# 3           1       1  female      1      0            113803   53.1000
# 4           0       3    male      0      0            373450    8.0500
# ..        ...     ...     ...    ...    ...               ...       ...
# 708         1       1  female      0      0            113781  151.5500
# 709         1       3    male      1      1              2661   15.2458
# 710         1       1  female      0      0          PC 17482   49.5042
# 711         0       1    male      0      0            113028   26.5500
# 712         1       1    male      1      0             19996   52.0000
#
# [713 rows x 7 columns]

# %%
set2=sd1.iloc[714:890,:]
set2
# Out:
#      Survived  Pclass     Sex  SibSp  Parch      Ticket     Fare
# 714         0       2    male      0      0      250647   13.000
# 715         0       3    male      0      0      348124    7.650
# 716         1       1  female      0      0    PC 17757  227.525
# 717         1       2  female      0      0       34218   10.500
# 718         0       3    male      0      0       36568   15.500
# ..        ...     ...     ...    ...    ...         ...      ...
# 885         0       3  female      0      5      382652   29.125
# 886         0       2    male      0      0      211536   13.000
# 887         1       1  female      0      0      112053   30.000
# 888         0       3  female      1      2  W./C. 6607   23.450
# 889         1       1    male      0      0      111369   30.000
#
# [176 rows x 7 columns]

# %%
one=sd1['Survived'].eq(1).sum()
one
# Out:
# 342

# %%
zero=sd1['Survived'].eq(0).sum()
zero
# Out:
# 549

# %%
data=[one,zero]
index=["Survived","Not Survived"]
df=pd.DataFrame(data=data,index=index)
df
# Out:
#                 0
# Survived      342
# Not Survived  549

# %%
df.plot.bar(rot=15)
